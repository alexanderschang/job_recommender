# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from random import random
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import StaleElementReferenceException

# %%
browser = webdriver.Safari()

url = 'http://twitter.com/PattySc60795990/statuses/1079891028092416000'
browser.get(url)

# %%
browser = webdriver.Safari()

base_url = 'https://www.glassdoor.com/blog/tag/job-search/'
browser.get(base_url)
query = browser.find_element_by_id("sc.keyword")
query.click()
query.clear()
time.sleep(random() * 0.1)
query.send_keys('machine learning engineer')
time.sleep(random() * 0.1)
return_button = browser.find_element_by_xpath('//*[@id="HeroSearchButton"]')
return_button.click()
time.sleep(random() * 0.1)

# %%
links = set()
data = []

# %%
pages = 17

for i in range(pages):
    print('-------currently on page ', i+1, '------------')
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    try:
        close = browser.find_element_by_class_name('modal_closeIcon')
        close.click()
        close.click()

    except:
        None

    try:
        close = browser.find_element_by_class('qual_x_close')
        close.click()
        close.click()
    except:
        None


    # salaries = [i.text for i in soup.find_all('span', class_='gray salary')]
    # locations = [i.text for i in soup.find_all('span', class_='subtle loc css-nq3w9f pr-xxsm')]
    # companies = [i.text for i in soup.find_all('a', class_='jobInfoItem jobTitle jobLink')][0::2]
    # titles = [i.text for i in soup.find_all('a', class_='jobInfoItem jobTitle jobLink')][1::2]
    # ratings = [i.text for i in soup.find_all('span', class_='compactStars')]

    job_buttons = browser.find_elements_by_class_name("jl")
    count = 0
    for job_button in job_buttons:
        try: 
            time.sleep(2)
            count+=1
            print('***job #', count)
            
            # Get rid of "x"
            try:
                x_button = browser.find_element_by_xpath('//*[@id="JAModal"]/div/div[2]/span')
                x_button.click()
            except:
                #print()
                pass

            job_button.click()
            browser.implicitly_wait(random()*2)
            
            try:
                job_description = browser.find_element_by_xpath('.//div[@class="jobDescriptionContent desc"]').text
            except:
                job_description = ''
                None
                
            try:
                salary = job_button.find_element_by_class_name('salary').text

            except:
                salary = -1


            summ = job_button.find_elements_by_class_name('jobInfoItem')
            try:
                company = summ[1].text
            except:
                company = ''
            try:
                title = summ[2].text
            except:
                title = ''
            try:
                location = summ[3].text
            except:
                location = ''
            try:
                rating = job_button.find_element_by_class_name('compactStars').text
            except:
                rating = -1

            try:
                job_tab = browser.find_element_by_class_name('scrollableTabs').find_elements_by_class_name('tab')[0]
            except:
                continue

            try:
                close = browser.find_element_by_class_name('modal_closeIcon')
                close.click()
                close.click()
            except:
                None
            try:
                close = browser.find_element_by_class('qual_x_close')
                close.click()
                close.click()
            except:
                None

            # Job descriptions (NOT right side)
            #try:
            #    job_descriptions = browser.find_element_by_xpath('//*[@id="JobDesc3437830919"]/div')

            #except:
            #    job_descriptions = ''
            #    None

            try:
                close = browser.find_element_by_class_name('modal_closeIcon')
                close.click()
                close.click()
            except:
                None
            try:
                close = browser.find_element_by_class('qual_x_close')
                close.click()
                close.click()
            except:
                None

            # Company Page (right side)
            try:
                company_tab = browser.find_element_by_class_name('scrollableTabs').find_elements_by_class_name('tab')[1]
                company_tab.click()
                company_tab.click()
            except:
                print('what')
            browser.implicitly_wait(2)
            soup = BeautifulSoup(browser.page_source, 'html.parser')
            try:
                company_labels = soup.find('div', class_='empBasicInfo').find_all('label')
                company_spans = soup.find('div', class_='empBasicInfo').find_all('span')
            except:
                company_labels = {}
                company_spans = {}

            d = {
                'company': company,
                'title': title,
                'location': location,
                'rating': rating,
                'descriptions': job_description,
                'salary': salary
            }

            for i, l in enumerate(company_labels):
                d[l.text] = company_spans[i].text

            data.append(d)
            
        except StaleElementReferenceException:
            print('page needs refresh')
            browser.refresh()

    nextButton = browser.find_element_by_xpath('//*[@id="FooterPageNav"]/div/ul/li[7]/a')
    time.sleep(5 + random() * 3)   
    #nextButton.click()
    nextButton.click()
# Out:
# -------currently on page  1 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# what
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# what
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  2 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# what
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# what
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# what
# -------currently on page  3 ------------
# ***job # 1
# ***job # 2
# what
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  4 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# what
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  5 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# what
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# what
# ***job # 19
# ***job # 20
# ***job # 21
# what
# ***job # 22
# ***job # 23
# what
# ***job # 24
# ***job # 25
# what
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# what
# -------currently on page  6 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  7 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# what
# ***job # 19
# ***job # 20
# what
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# what
# -------currently on page  8 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  9 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# ***job # 14
# what
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# ***job # 30
# ***job # 31
# ***job # 32
# -------currently on page  10 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ***job # 5
# ***job # 6
# ***job # 7
# ***job # 8
# ***job # 9
# ***job # 10
# ***job # 11
# ***job # 12
# ***job # 13
# what
# ***job # 14
# ***job # 15
# ***job # 16
# ***job # 17
# ***job # 18
# ***job # 19
# ***job # 20
# ***job # 21
# ***job # 22
# ***job # 23
# ***job # 24
# ***job # 25
# ***job # 26
# ***job # 27
# ***job # 28
# ***job # 29
# what
# ***job # 30
# ***job # 31
# what
# ***job # 32
# -------currently on page  11 ------------
# ***job # 1
# ***job # 2
# ***job # 3
# ***job # 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-a66078adcbcf> in <module>
#     123                 print('what')
#     124             browser.implicitly_wait(2)
# --> 125             soup = BeautifulSoup(browser.page_source, 'html.parser')
#     126             try:
#     127                 company_labels = soup.find('div', class_='empBasicInfo').find_all('label')
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     323             self.reset()
#     324             try:
# --> 325                 self._feed()
#     326                 success = True
#     327                 break
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     397         self.builder.reset()
#     398
# --> 399         self.builder.feed(self.markup)
#     400         # Close out any unfinished strings and close all the open tags.
#     401         self.endData()
#
# /anaconda3/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     337         parser.soup = self.soup
#     338         try:
# --> 339             parser.feed(markup)
#     340             parser.close()
#     341         except HTMLParseError as e:
#
# /anaconda3/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /anaconda3/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /anaconda3/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     300     # Internal -- handle starttag, return end or -1 if not terminated
#     301     def parse_starttag(self, i):
# --> 302         self.__starttag_text = None
#     303         endpos = self.check_for_whole_start_tag(i)
#     304         if endpos < 0:
#
# KeyboardInterrupt:

# %%
browser.refresh()

pageToGo = 14
for i in range(pageToGo):
    try:
        close = browser.find_element_by_class_name('modal_closeIcon')
        close.click()
        close.click()
    except:
        None
        
    #nextButton = browser.find_element_by_xpath('//*[@id="FooterPageNav"]/div/ul/li[7]/a')
    nextButton = browser.find_element_by_class_name('next')
    time.sleep(3)
    nextButton.click()
    
    try:
        nextButton.click()
    except:
        pass 
    #nextButton.click()
    time.sleep(2)

# %%
features = set()

for d in data:
    features.update( d.keys() )

for d in data:
    for feat in features:
        if feat not in d:
            d[feat] = -1
df = pd.DataFrame(data, columns = features)

df.to_csv('glassdoor_data.csv')

# %%
df_edited = df.drop_duplicates()

# %%
len(df_edited)
# Out:
# 450

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from random import random
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
browser = webdriver.Safari()
base_url = 'https://www.glassdoor.com/blog/tag/job-search/'
browser.get(base_url)

# %%
keyword = 'machine learning engineer'

query = browser.find_element_by_id("sc.keyword")
query.click()
query.clear()
time.sleep(random()*1)
query.send_keys(keyword)
time.sleep(random()*0.1)
return_button = browser.find_element_by_xpath('//*[@id="HeroSearchButton"]')
return_button.click()
time.sleep(random() * 0.1)

links = set()

# %%
pageToGo = 30

for i in range(pageToGo):
    
    #try and catch clauses
    try:
        close = browser.find_element_by_class_name('modal_closeIcon')
        close.click()
        close.click()
    except:
        None
    try:
        close = browser.find_element_by_class('qual_x_close')
        close.click()
        close.click()
    except:
        None
    
    #get job_link
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    grids = soup.find('ul', class_='jlGrid hover').find_all('a', href=True)
    for g in grids:
        links.add(g['href'])
    
    #go to next page
    nextButton = browser.find_element_by_class_name('next')   
    time.sleep(2)
    nextButton.click()
    nextButton.click()
    time.sleep(2)

browser.close()

# %%
f = open("ml_engineer_links.txt", "w")
for link in links:
    f.write(link)
    f.write('\n')
f.close()

# %%
links = list(links)
web_pages = []
count=0

# %%
len(links[474:])
# Out:
# 452

# %%
import requests

#for l in links[474:]:
for l in links:
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    contents = requests.get(l, headers = headers)
    time.sleep(5+random()*3)
    if  contents.status_code != requests.codes.ok:
        print('This is not OK. 403')
        print('Count: ', count)
        print('Will Try again')
        time.sleep(20)
        contents = requests.get(l, headers = headers)
        if  contents.status_code != requests.codes.ok:
            print('failed')
            break
    if count % 10 == 0:
        print('currently on #', count, 'status: ', contents)
        if count % 100 == 0:
            temp = BeautifulSoup(contents.text, 'html.parser')
            jobDescription = soup.find_all('div', id='JobDescriptionContainer')
            if len(jobDescription) < 1:
                print('No job description...')
                print('Check carefully')
    web_pages.append(contents.text)
    count += 1
# Out:
# currently on # 0 status:  <Response [200]>
# This is not OK. 403
# Count:  10
# Will Try again
# currently on # 10 status:  <Response [200]>
# currently on # 20 status:  <Response [200]>
# currently on # 30 status:  <Response [200]>
# currently on # 40 status:  <Response [200]>
# currently on # 50 status:  <Response [200]>
# currently on # 60 status:  <Response [200]>
# currently on # 70 status:  <Response [200]>
# currently on # 80 status:  <Response [200]>
# currently on # 90 status:  <Response [200]>
# currently on # 100 status:  <Response [200]>
# currently on # 110 status:  <Response [200]>
# currently on # 120 status:  <Response [200]>
# currently on # 130 status:  <Response [200]>
# This is not OK. 403
# Count:  131
# Will Try again
# currently on # 140 status:  <Response [200]>
# currently on # 150 status:  <Response [200]>
# currently on # 160 status:  <Response [200]>
# currently on # 170 status:  <Response [200]>
# currently on # 180 status:  <Response [200]>
# This is not OK. 403
# Count:  185
# Will Try again
# currently on # 190 status:  <Response [200]>
# currently on # 200 status:  <Response [200]>
# currently on # 210 status:  <Response [200]>
# currently on # 220 status:  <Response [200]>
# currently on # 230 status:  <Response [200]>
# currently on # 240 status:  <Response [200]>
# currently on # 250 status:  <Response [200]>
# currently on # 260 status:  <Response [200]>
# currently on # 270 status:  <Response [200]>
# currently on # 280 status:  <Response [200]>
# currently on # 290 status:  <Response [200]>
# currently on # 300 status:  <Response [200]>
# currently on # 310 status:  <Response [200]>
# currently on # 320 status:  <Response [200]>
# currently on # 330 status:  <Response [200]>
# currently on # 340 status:  <Response [200]>
# currently on # 350 status:  <Response [200]>
# currently on # 360 status:  <Response [200]>
# currently on # 370 status:  <Response [200]>
# currently on # 380 status:  <Response [200]>
# currently on # 390 status:  <Response [200]>
# currently on # 400 status:  <Response [200]>
# currently on # 410 status:  <Response [200]>
# currently on # 420 status:  <Response [200]>
# currently on # 430 status:  <Response [200]>
# currently on # 440 status:  <Response [200]>
# currently on # 450 status:  <Response [200]>
# currently on # 460 status:  <Response [200]>
# currently on # 470 status:  <Response [200]>
# currently on # 480 status:  <Response [200]>
# currently on # 490 status:  <Response [200]>
# currently on # 500 status:  <Response [200]>
# currently on # 510 status:  <Response [200]>
# currently on # 520 status:  <Response [200]>
# currently on # 530 status:  <Response [200]>
# currently on # 540 status:  <Response [200]>
# currently on # 550 status:  <Response [200]>
# currently on # 560 status:  <Response [200]>
# currently on # 570 status:  <Response [200]>
# currently on # 580 status:  <Response [200]>
# currently on # 590 status:  <Response [200]>
# currently on # 600 status:  <Response [200]>
# currently on # 610 status:  <Response [200]>
# currently on # 620 status:  <Response [200]>
# currently on # 630 status:  <Response [200]>
# currently on # 640 status:  <Response [200]>
# currently on # 650 status:  <Response [200]>
# currently on # 660 status:  <Response [200]>
# currently on # 670 status:  <Response [200]>
# currently on # 680 status:  <Response [200]>
# This is not OK. 403
# Count:  689
# Will Try again
# currently on # 690 status:  <Response [200]>
# currently on # 700 status:  <Response [200]>
# currently on # 710 status:  <Response [200]>
# currently on # 720 status:  <Response [200]>
# currently on # 730 status:  <Response [200]>
# currently on # 740 status:  <Response [200]>
# currently on # 750 status:  <Response [200]>
# currently on # 760 status:  <Response [200]>
# currently on # 770 status:  <Response [200]>
# currently on # 780 status:  <Response [200]>
# currently on # 790 status:  <Response [200]>
# currently on # 800 status:  <Response [200]>
# currently on # 810 status:  <Response [200]>
# currently on # 820 status:  <Response [200]>
# currently on # 830 status:  <Response [200]>
# currently on # 840 status:  <Response [200]>
# currently on # 850 status:  <Response [200]>
# currently on # 860 status:  <Response [200]>
# currently on # 870 status:  <Response [200]>
# currently on # 880 status:  <Response [200]>
# currently on # 890 status:  <Response [200]>
# currently on # 900 status:  <Response [200]>
# currently on # 910 status:  <Response [200]>
# currently on # 920 status:  <Response [200]>

# %%
#Save original html file to archive. #too big, do not include it in github. Share using drive.
import os
os.makedirs(os.path.dirname('./archive_web_page/' + keyword.replace(' ', '_') + '/'), exist_ok=True)

for i, web_page in enumerate(web_pages):
    soup = BeautifulSoup(web_page, 'html.parser')
    filename = './archive_web_page/' + keyword.replace(' ', '_') + '/' + str(i) + '_' + str(soup.title.text).replace(" ", "_").replace('/', '_') + '.html'
    file = open(filename, "w")
    file.write(web_page)
    file.close()
print('Write Complete.')
# Out:
# Write Complete.

# %%
data = []

# %%
for i, web_page in enumerate(web_pages):
    print('---------Currently converting web page # ', i)
    soup = BeautifulSoup(web_page, 'html.parser')
    try:
        company_name = soup.find('div', class_='css-16nw49e e11nt52q1').find(text=True, recursive=False)
    except:
        print('No company name')
        company_name = ''
    try:
        rating = soup.find('span', class_='css-1pmc6te e11nt52q3').find(text=True, recursive=False)
    except:
        print('No rating')
        rating = ''
    try:
        title = soup.find('div', class_='css-17x2pwl e11nt52q5').find(text=True, recursive=False)
    except:
        print('No title')
        title = ''
    try:
        location = soup.find('div', class_='css-13et3b1 e11nt52q2').find(text=True, recursive=False)
    except:
        print('No location')
        location = ''
        
    try:
        estimate_salary_range = soup.find('span', class_='small css-10zcshf e1v3ed7e1').find(text=True, recursive=False)
    except:
        print('no estimate_salary_range')
        estimate_salary_range = '-1'
    try:
        estimate_salary_point = soup.find('h2', class_='css-mena9f e10nsqxw5').find(text=True, recursive=False)
    except:
        print('no estimate_salary_point')
        estimate_salary_point = '-1'
    try:
        job_description = soup.find('div', class_='desc css-58vpdc ecgq1xb3').text
    except:
        print('no job_description')
        job_description = ''
    
    try:
        company_link = soup.find('a', class_='mt-0 css-1sltc87 epu0oo21')['href']
    except:
        print('no company link')
        company_link = ''
    entry = {
        'title': str(soup.title.text).replace(" ", "_"),
        'company_name': company_name,
        'rating': rating,
        'title': title,
        'location': location,
        'estimate_salary_range': estimate_salary_range,
        'estimate_salary_point': estimate_salary_point,
        'job_description': job_description,
        'company_link': company_link
        }
    
    data.append(entry)
# Out:
# ---------Currently converting web page #  0
# ---------Currently converting web page #  1
# ---------Currently converting web page #  2
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  3
# ---------Currently converting web page #  4
# ---------Currently converting web page #  5
# ---------Currently converting web page #  6
# ---------Currently converting web page #  7
# ---------Currently converting web page #  8
# ---------Currently converting web page #  9
# ---------Currently converting web page #  10
# ---------Currently converting web page #  11
# ---------Currently converting web page #  12
# ---------Currently converting web page #  13
# ---------Currently converting web page #  14
# ---------Currently converting web page #  15
# ---------Currently converting web page #  16
# ---------Currently converting web page #  17
# ---------Currently converting web page #  18
# ---------Currently converting web page #  19
# ---------Currently converting web page #  20
# ---------Currently converting web page #  21
# ---------Currently converting web page #  22
# ---------Currently converting web page #  23
# ---------Currently converting web page #  24
# ---------Currently converting web page #  25
# ---------Currently converting web page #  26
# ---------Currently converting web page #  27
# ---------Currently converting web page #  28
# ---------Currently converting web page #  29
# ---------Currently converting web page #  30
# ---------Currently converting web page #  31
# ---------Currently converting web page #  32
# ---------Currently converting web page #  33
# ---------Currently converting web page #  34
# ---------Currently converting web page #  35
# ---------Currently converting web page #  36
# ---------Currently converting web page #  37
# ---------Currently converting web page #  38
# ---------Currently converting web page #  39
# ---------Currently converting web page #  40
# ---------Currently converting web page #  41
# ---------Currently converting web page #  42
# ---------Currently converting web page #  43
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  44
# ---------Currently converting web page #  45
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  46
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  47
# ---------Currently converting web page #  48
# ---------Currently converting web page #  49
# ---------Currently converting web page #  50
# ---------Currently converting web page #  51
# ---------Currently converting web page #  52
# ---------Currently converting web page #  53
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  54
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  55
# ---------Currently converting web page #  56
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  57
# ---------Currently converting web page #  58
# ---------Currently converting web page #  59
# ---------Currently converting web page #  60
# ---------Currently converting web page #  61
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  62
# ---------Currently converting web page #  63
# ---------Currently converting web page #  64
# ---------Currently converting web page #  65
# ---------Currently converting web page #  66
# ---------Currently converting web page #  67
# ---------Currently converting web page #  68
# ---------Currently converting web page #  69
# ---------Currently converting web page #  70
# ---------Currently converting web page #  71
# ---------Currently converting web page #  72
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  73
# ---------Currently converting web page #  74
# ---------Currently converting web page #  75
# ---------Currently converting web page #  76
# ---------Currently converting web page #  77
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  78
# ---------Currently converting web page #  79
# ---------Currently converting web page #  80
# ---------Currently converting web page #  81
# ---------Currently converting web page #  82
# ---------Currently converting web page #  83
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  84
# ---------Currently converting web page #  85
# ---------Currently converting web page #  86
# ---------Currently converting web page #  87
# ---------Currently converting web page #  88
# ---------Currently converting web page #  89
# ---------Currently converting web page #  90
# ---------Currently converting web page #  91
# ---------Currently converting web page #  92
# ---------Currently converting web page #  93
# ---------Currently converting web page #  94
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  95
# ---------Currently converting web page #  96
# ---------Currently converting web page #  97
# ---------Currently converting web page #  98
# ---------Currently converting web page #  99
# ---------Currently converting web page #  100
# ---------Currently converting web page #  101
# ---------Currently converting web page #  102
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  103
# ---------Currently converting web page #  104
# ---------Currently converting web page #  105
# ---------Currently converting web page #  106
# ---------Currently converting web page #  107
# ---------Currently converting web page #  108
# ---------Currently converting web page #  109
# ---------Currently converting web page #  110
# ---------Currently converting web page #  111
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  112
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  113
# ---------Currently converting web page #  114
# ---------Currently converting web page #  115
# ---------Currently converting web page #  116
# ---------Currently converting web page #  117
# ---------Currently converting web page #  118
# ---------Currently converting web page #  119
# ---------Currently converting web page #  120
# ---------Currently converting web page #  121
# ---------Currently converting web page #  122
# ---------Currently converting web page #  123
# ---------Currently converting web page #  124
# ---------Currently converting web page #  125
# ---------Currently converting web page #  126
# ---------Currently converting web page #  127
# ---------Currently converting web page #  128
# ---------Currently converting web page #  129
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  130
# ---------Currently converting web page #  131
# ---------Currently converting web page #  132
# ---------Currently converting web page #  133
# ---------Currently converting web page #  134
# ---------Currently converting web page #  135
# ---------Currently converting web page #  136
# ---------Currently converting web page #  137
# ---------Currently converting web page #  138
# ---------Currently converting web page #  139
# ---------Currently converting web page #  140
# ---------Currently converting web page #  141
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  142
# ---------Currently converting web page #  143
# ---------Currently converting web page #  144
# ---------Currently converting web page #  145
# ---------Currently converting web page #  146
# ---------Currently converting web page #  147
# ---------Currently converting web page #  148
# ---------Currently converting web page #  149
# ---------Currently converting web page #  150
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  151
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  152
# ---------Currently converting web page #  153
# ---------Currently converting web page #  154
# ---------Currently converting web page #  155
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  156
# ---------Currently converting web page #  157
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  158
# ---------Currently converting web page #  159
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  160
# ---------Currently converting web page #  161
# ---------Currently converting web page #  162
# ---------Currently converting web page #  163
# ---------Currently converting web page #  164
# ---------Currently converting web page #  165
# ---------Currently converting web page #  166
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  167
# ---------Currently converting web page #  168
# ---------Currently converting web page #  169
# ---------Currently converting web page #  170
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  171
# ---------Currently converting web page #  172
# ---------Currently converting web page #  173
# ---------Currently converting web page #  174
# ---------Currently converting web page #  175
# ---------Currently converting web page #  176
# ---------Currently converting web page #  177
# ---------Currently converting web page #  178
# ---------Currently converting web page #  179
# ---------Currently converting web page #  180
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  181
# ---------Currently converting web page #  182
# ---------Currently converting web page #  183
# ---------Currently converting web page #  184
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  185
# ---------Currently converting web page #  186
# ---------Currently converting web page #  187
# ---------Currently converting web page #  188
# ---------Currently converting web page #  189
# ---------Currently converting web page #  190
# ---------Currently converting web page #  191
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  192
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  193
# ---------Currently converting web page #  194
# ---------Currently converting web page #  195
# ---------Currently converting web page #  196
# ---------Currently converting web page #  197
# ---------Currently converting web page #  198
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  199
# ---------Currently converting web page #  200
# ---------Currently converting web page #  201
# ---------Currently converting web page #  202
# ---------Currently converting web page #  203
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  204
# ---------Currently converting web page #  205
# ---------Currently converting web page #  206
# ---------Currently converting web page #  207
# ---------Currently converting web page #  208
# ---------Currently converting web page #  209
# ---------Currently converting web page #  210
# ---------Currently converting web page #  211
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  212
# ---------Currently converting web page #  213
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  214
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  215
# ---------Currently converting web page #  216
# ---------Currently converting web page #  217
# ---------Currently converting web page #  218
# ---------Currently converting web page #  219
# ---------Currently converting web page #  220
# ---------Currently converting web page #  221
# ---------Currently converting web page #  222
# ---------Currently converting web page #  223
# ---------Currently converting web page #  224
# ---------Currently converting web page #  225
# ---------Currently converting web page #  226
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  227
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  228
# ---------Currently converting web page #  229
# ---------Currently converting web page #  230
# ---------Currently converting web page #  231
# ---------Currently converting web page #  232
# ---------Currently converting web page #  233
# ---------Currently converting web page #  234
# ---------Currently converting web page #  235
# ---------Currently converting web page #  236
# ---------Currently converting web page #  237
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  238
# ---------Currently converting web page #  239
# no estimate_salary_point
# no job_description
# ---------Currently converting web page #  240
# ---------Currently converting web page #  241
# ---------Currently converting web page #  242
# ---------Currently converting web page #  243
# ---------Currently converting web page #  244
# ---------Currently converting web page #  245
# ---------Currently converting web page #  246
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  247
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  248
# no estimate_salary_point
# no job_description
# ---------Currently converting web page #  249
# ---------Currently converting web page #  250
# ---------Currently converting web page #  251
# ---------Currently converting web page #  252
# ---------Currently converting web page #  253
# ---------Currently converting web page #  254
# ---------Currently converting web page #  255
# ---------Currently converting web page #  256
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  257
# ---------Currently converting web page #  258
# ---------Currently converting web page #  259
# ---------Currently converting web page #  260
# ---------Currently converting web page #  261
# ---------Currently converting web page #  262
# ---------Currently converting web page #  263
# ---------Currently converting web page #  264
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  265
# ---------Currently converting web page #  266
# ---------Currently converting web page #  267
# ---------Currently converting web page #  268
# ---------Currently converting web page #  269
# ---------Currently converting web page #  270
# ---------Currently converting web page #  271
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  272
# ---------Currently converting web page #  273
# ---------Currently converting web page #  274
# ---------Currently converting web page #  275
# ---------Currently converting web page #  276
# ---------Currently converting web page #  277
# ---------Currently converting web page #  278
# No rating
# ---------Currently converting web page #  279
# ---------Currently converting web page #  280
# ---------Currently converting web page #  281
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  282
# ---------Currently converting web page #  283
# ---------Currently converting web page #  284
# ---------Currently converting web page #  285
# ---------Currently converting web page #  286
# ---------Currently converting web page #  287
# ---------Currently converting web page #  288
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  289
# ---------Currently converting web page #  290
# ---------Currently converting web page #  291
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  292
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  293
# ---------Currently converting web page #  294
# ---------Currently converting web page #  295
# ---------Currently converting web page #  296
# ---------Currently converting web page #  297
# ---------Currently converting web page #  298
# ---------Currently converting web page #  299
# ---------Currently converting web page #  300
# ---------Currently converting web page #  301
# ---------Currently converting web page #  302
# ---------Currently converting web page #  303
# ---------Currently converting web page #  304
# ---------Currently converting web page #  305
# ---------Currently converting web page #  306
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  307
# ---------Currently converting web page #  308
# ---------Currently converting web page #  309
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  310
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  311
# ---------Currently converting web page #  312
# ---------Currently converting web page #  313
# ---------Currently converting web page #  314
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  315
# ---------Currently converting web page #  316
# ---------Currently converting web page #  317
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  318
# ---------Currently converting web page #  319
# ---------Currently converting web page #  320
# ---------Currently converting web page #  321
# ---------Currently converting web page #  322
# ---------Currently converting web page #  323
# ---------Currently converting web page #  324
# ---------Currently converting web page #  325
# ---------Currently converting web page #  326
# ---------Currently converting web page #  327
# ---------Currently converting web page #  328
# ---------Currently converting web page #  329
# ---------Currently converting web page #  330
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  331
# ---------Currently converting web page #  332
# ---------Currently converting web page #  333
# ---------Currently converting web page #  334
# ---------Currently converting web page #  335
# ---------Currently converting web page #  336
# ---------Currently converting web page #  337
# ---------Currently converting web page #  338
# ---------Currently converting web page #  339
# ---------Currently converting web page #  340
# ---------Currently converting web page #  341
# ---------Currently converting web page #  342
# ---------Currently converting web page #  343
# ---------Currently converting web page #  344
# ---------Currently converting web page #  345
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  346
# ---------Currently converting web page #  347
# ---------Currently converting web page #  348
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  349
# ---------Currently converting web page #  350
# ---------Currently converting web page #  351
# ---------Currently converting web page #  352
# ---------Currently converting web page #  353
# ---------Currently converting web page #  354
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  355
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  356
# ---------Currently converting web page #  357
# ---------Currently converting web page #  358
# ---------Currently converting web page #  359
# ---------Currently converting web page #  360
# ---------Currently converting web page #  361
# ---------Currently converting web page #  362
# ---------Currently converting web page #  363
# ---------Currently converting web page #  364
# ---------Currently converting web page #  365
# ---------Currently converting web page #  366
# ---------Currently converting web page #  367
# ---------Currently converting web page #  368
# ---------Currently converting web page #  369
# ---------Currently converting web page #  370
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  371
# ---------Currently converting web page #  372
# ---------Currently converting web page #  373
# ---------Currently converting web page #  374
# ---------Currently converting web page #  375
# ---------Currently converting web page #  376
# ---------Currently converting web page #  377
# ---------Currently converting web page #  378
# ---------Currently converting web page #  379
# ---------Currently converting web page #  380
# ---------Currently converting web page #  381
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  382
# ---------Currently converting web page #  383
# ---------Currently converting web page #  384
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  385
# ---------Currently converting web page #  386
# ---------Currently converting web page #  387
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  388
# ---------Currently converting web page #  389
# ---------Currently converting web page #  390
# ---------Currently converting web page #  391
# ---------Currently converting web page #  392
# ---------Currently converting web page #  393
# ---------Currently converting web page #  394
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  395
# ---------Currently converting web page #  396
# ---------Currently converting web page #  397
# ---------Currently converting web page #  398
# ---------Currently converting web page #  399
# ---------Currently converting web page #  400
# ---------Currently converting web page #  401
# ---------Currently converting web page #  402
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  403
# ---------Currently converting web page #  404
# ---------Currently converting web page #  405
# ---------Currently converting web page #  406
# ---------Currently converting web page #  407
# ---------Currently converting web page #  408
# ---------Currently converting web page #  409
# ---------Currently converting web page #  410
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  411
# ---------Currently converting web page #  412
# ---------Currently converting web page #  413
# ---------Currently converting web page #  414
# ---------Currently converting web page #  415
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  416
# ---------Currently converting web page #  417
# ---------Currently converting web page #  418
# ---------Currently converting web page #  419
# ---------Currently converting web page #  420
# ---------Currently converting web page #  421
# ---------Currently converting web page #  422
# ---------Currently converting web page #  423
# ---------Currently converting web page #  424
# ---------Currently converting web page #  425
# ---------Currently converting web page #  426
# ---------Currently converting web page #  427
# ---------Currently converting web page #  428
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  429
# ---------Currently converting web page #  430
# ---------Currently converting web page #  431
# ---------Currently converting web page #  432
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  433
# ---------Currently converting web page #  434
# ---------Currently converting web page #  435
# ---------Currently converting web page #  436
# ---------Currently converting web page #  437
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  438
# ---------Currently converting web page #  439
# ---------Currently converting web page #  440
# ---------Currently converting web page #  441
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  442
# ---------Currently converting web page #  443
# ---------Currently converting web page #  444
# ---------Currently converting web page #  445
# ---------Currently converting web page #  446
# ---------Currently converting web page #  447
# ---------Currently converting web page #  448
# ---------Currently converting web page #  449
# ---------Currently converting web page #  450
# ---------Currently converting web page #  451
# ---------Currently converting web page #  452
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  453
# no company link
# ---------Currently converting web page #  454
# ---------Currently converting web page #  455
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  456
# ---------Currently converting web page #  457
# ---------Currently converting web page #  458
# ---------Currently converting web page #  459
# ---------Currently converting web page #  460
# ---------Currently converting web page #  461
# ---------Currently converting web page #  462
# ---------Currently converting web page #  463
# ---------Currently converting web page #  464
# ---------Currently converting web page #  465
# ---------Currently converting web page #  466
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  467
# ---------Currently converting web page #  468
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  469
# ---------Currently converting web page #  470
# ---------Currently converting web page #  471
# ---------Currently converting web page #  472
# ---------Currently converting web page #  473
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  474
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  475
# ---------Currently converting web page #  476
# ---------Currently converting web page #  477
# ---------Currently converting web page #  478
# ---------Currently converting web page #  479
# ---------Currently converting web page #  480
# ---------Currently converting web page #  481
# ---------Currently converting web page #  482
# ---------Currently converting web page #  483
# ---------Currently converting web page #  484
# ---------Currently converting web page #  485
# ---------Currently converting web page #  486
# ---------Currently converting web page #  487
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  488
# ---------Currently converting web page #  489
# ---------Currently converting web page #  490
# ---------Currently converting web page #  491
# ---------Currently converting web page #  492
# ---------Currently converting web page #  493
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  494
# ---------Currently converting web page #  495
# ---------Currently converting web page #  496
# ---------Currently converting web page #  497
# ---------Currently converting web page #  498
# ---------Currently converting web page #  499
# ---------Currently converting web page #  500
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  501
# ---------Currently converting web page #  502
# ---------Currently converting web page #  503
# ---------Currently converting web page #  504
# ---------Currently converting web page #  505
# ---------Currently converting web page #  506
# ---------Currently converting web page #  507
# ---------Currently converting web page #  508
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  509
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  510
# ---------Currently converting web page #  511
# ---------Currently converting web page #  512
# ---------Currently converting web page #  513
# ---------Currently converting web page #  514
# ---------Currently converting web page #  515
# ---------Currently converting web page #  516
# ---------Currently converting web page #  517
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  518
# ---------Currently converting web page #  519
# ---------Currently converting web page #  520
# ---------Currently converting web page #  521
# ---------Currently converting web page #  522
# ---------Currently converting web page #  523
# ---------Currently converting web page #  524
# ---------Currently converting web page #  525
# ---------Currently converting web page #  526
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  527
# ---------Currently converting web page #  528
# ---------Currently converting web page #  529
# ---------Currently converting web page #  530
# ---------Currently converting web page #  531
# ---------Currently converting web page #  532
# ---------Currently converting web page #  533
# ---------Currently converting web page #  534
# ---------Currently converting web page #  535
# ---------Currently converting web page #  536
# ---------Currently converting web page #  537
# ---------Currently converting web page #  538
# ---------Currently converting web page #  539
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  540
# ---------Currently converting web page #  541
# ---------Currently converting web page #  542
# ---------Currently converting web page #  543
# ---------Currently converting web page #  544
# ---------Currently converting web page #  545
# ---------Currently converting web page #  546
# ---------Currently converting web page #  547
# ---------Currently converting web page #  548
# ---------Currently converting web page #  549
# ---------Currently converting web page #  550
# ---------Currently converting web page #  551
# ---------Currently converting web page #  552
# ---------Currently converting web page #  553
# ---------Currently converting web page #  554
# ---------Currently converting web page #  555
# ---------Currently converting web page #  556
# ---------Currently converting web page #  557
# ---------Currently converting web page #  558
# ---------Currently converting web page #  559
# ---------Currently converting web page #  560
# No rating
# no company link
# ---------Currently converting web page #  561
# ---------Currently converting web page #  562
# ---------Currently converting web page #  563
# ---------Currently converting web page #  564
# ---------Currently converting web page #  565
# ---------Currently converting web page #  566
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  567
# ---------Currently converting web page #  568
# ---------Currently converting web page #  569
# ---------Currently converting web page #  570
# ---------Currently converting web page #  571
# ---------Currently converting web page #  572
# ---------Currently converting web page #  573
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  574
# ---------Currently converting web page #  575
# ---------Currently converting web page #  576
# ---------Currently converting web page #  577
# ---------Currently converting web page #  578
# ---------Currently converting web page #  579
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  580
# ---------Currently converting web page #  581
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  582
# ---------Currently converting web page #  583
# ---------Currently converting web page #  584
# ---------Currently converting web page #  585
# ---------Currently converting web page #  586
# ---------Currently converting web page #  587
# ---------Currently converting web page #  588
# ---------Currently converting web page #  589
# ---------Currently converting web page #  590
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  591
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  592
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  593
# ---------Currently converting web page #  594
# ---------Currently converting web page #  595
# ---------Currently converting web page #  596
# ---------Currently converting web page #  597
# ---------Currently converting web page #  598
# ---------Currently converting web page #  599
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  600
# ---------Currently converting web page #  601
# ---------Currently converting web page #  602
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  603
# ---------Currently converting web page #  604
# ---------Currently converting web page #  605
# No rating
# no company link
# ---------Currently converting web page #  606
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  607
# ---------Currently converting web page #  608
# ---------Currently converting web page #  609
# ---------Currently converting web page #  610
# ---------Currently converting web page #  611
# ---------Currently converting web page #  612
# ---------Currently converting web page #  613
# ---------Currently converting web page #  614
# ---------Currently converting web page #  615
# ---------Currently converting web page #  616
# ---------Currently converting web page #  617
# ---------Currently converting web page #  618
# ---------Currently converting web page #  619
# ---------Currently converting web page #  620
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  621
# ---------Currently converting web page #  622
# ---------Currently converting web page #  623
# ---------Currently converting web page #  624
# ---------Currently converting web page #  625
# ---------Currently converting web page #  626
# ---------Currently converting web page #  627
# ---------Currently converting web page #  628
# ---------Currently converting web page #  629
# ---------Currently converting web page #  630
# ---------Currently converting web page #  631
# ---------Currently converting web page #  632
# ---------Currently converting web page #  633
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  634
# ---------Currently converting web page #  635
# ---------Currently converting web page #  636
# ---------Currently converting web page #  637
# ---------Currently converting web page #  638
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  639
# ---------Currently converting web page #  640
# ---------Currently converting web page #  641
# ---------Currently converting web page #  642
# ---------Currently converting web page #  643
# ---------Currently converting web page #  644
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  645
# ---------Currently converting web page #  646
# ---------Currently converting web page #  647
# ---------Currently converting web page #  648
# ---------Currently converting web page #  649
# ---------Currently converting web page #  650
# ---------Currently converting web page #  651
# ---------Currently converting web page #  652
# ---------Currently converting web page #  653
# ---------Currently converting web page #  654
# ---------Currently converting web page #  655
# ---------Currently converting web page #  656
# ---------Currently converting web page #  657
# ---------Currently converting web page #  658
# ---------Currently converting web page #  659
# No rating
# ---------Currently converting web page #  660
# ---------Currently converting web page #  661
# ---------Currently converting web page #  662
# ---------Currently converting web page #  663
# ---------Currently converting web page #  664
# ---------Currently converting web page #  665
# ---------Currently converting web page #  666
# ---------Currently converting web page #  667
# ---------Currently converting web page #  668
# ---------Currently converting web page #  669
# ---------Currently converting web page #  670
# ---------Currently converting web page #  671
# ---------Currently converting web page #  672
# ---------Currently converting web page #  673
# ---------Currently converting web page #  674
# ---------Currently converting web page #  675
# ---------Currently converting web page #  676
# ---------Currently converting web page #  677
# ---------Currently converting web page #  678
# ---------Currently converting web page #  679
# ---------Currently converting web page #  680
# ---------Currently converting web page #  681
# ---------Currently converting web page #  682
# ---------Currently converting web page #  683
# ---------Currently converting web page #  684
# ---------Currently converting web page #  685
# ---------Currently converting web page #  686
# ---------Currently converting web page #  687
# ---------Currently converting web page #  688
# ---------Currently converting web page #  689
# ---------Currently converting web page #  690
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  691
# ---------Currently converting web page #  692
# ---------Currently converting web page #  693
# ---------Currently converting web page #  694
# ---------Currently converting web page #  695
# ---------Currently converting web page #  696
# ---------Currently converting web page #  697
# ---------Currently converting web page #  698
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  699
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  700
# ---------Currently converting web page #  701
# ---------Currently converting web page #  702
# ---------Currently converting web page #  703
# ---------Currently converting web page #  704
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  705
# ---------Currently converting web page #  706
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  707
# ---------Currently converting web page #  708
# ---------Currently converting web page #  709
# ---------Currently converting web page #  710
# ---------Currently converting web page #  711
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  712
# ---------Currently converting web page #  713
# ---------Currently converting web page #  714
# ---------Currently converting web page #  715
# ---------Currently converting web page #  716
# ---------Currently converting web page #  717
# ---------Currently converting web page #  718
# ---------Currently converting web page #  719
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  720
# ---------Currently converting web page #  721
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  722
# ---------Currently converting web page #  723
# ---------Currently converting web page #  724
# ---------Currently converting web page #  725
# ---------Currently converting web page #  726
# No rating
# ---------Currently converting web page #  727
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  728
# ---------Currently converting web page #  729
# no estimate_salary_point
# ---------Currently converting web page #  730
# ---------Currently converting web page #  731
# ---------Currently converting web page #  732
# ---------Currently converting web page #  733
# ---------Currently converting web page #  734
# ---------Currently converting web page #  735
# No rating
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  736
# ---------Currently converting web page #  737
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  738
# ---------Currently converting web page #  739
# ---------Currently converting web page #  740
# ---------Currently converting web page #  741
# ---------Currently converting web page #  742
# ---------Currently converting web page #  743
# ---------Currently converting web page #  744
# ---------Currently converting web page #  745
# ---------Currently converting web page #  746
# ---------Currently converting web page #  747
# ---------Currently converting web page #  748
# ---------Currently converting web page #  749
# ---------Currently converting web page #  750
# ---------Currently converting web page #  751
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  752
# ---------Currently converting web page #  753
# ---------Currently converting web page #  754
# ---------Currently converting web page #  755
# No rating
# no estimate_salary_point
# ---------Currently converting web page #  756
# ---------Currently converting web page #  757
# ---------Currently converting web page #  758
# ---------Currently converting web page #  759
# ---------Currently converting web page #  760
# ---------Currently converting web page #  761
# ---------Currently converting web page #  762
# ---------Currently converting web page #  763
# ---------Currently converting web page #  764
# ---------Currently converting web page #  765
# ---------Currently converting web page #  766
# ---------Currently converting web page #  767
# ---------Currently converting web page #  768
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  769
# ---------Currently converting web page #  770
# ---------Currently converting web page #  771
# ---------Currently converting web page #  772
# ---------Currently converting web page #  773
# ---------Currently converting web page #  774
# ---------Currently converting web page #  775
# ---------Currently converting web page #  776
# ---------Currently converting web page #  777
# ---------Currently converting web page #  778
# ---------Currently converting web page #  779
# ---------Currently converting web page #  780
# ---------Currently converting web page #  781
# ---------Currently converting web page #  782
# ---------Currently converting web page #  783
# ---------Currently converting web page #  784
# ---------Currently converting web page #  785
# ---------Currently converting web page #  786
# ---------Currently converting web page #  787
# ---------Currently converting web page #  788
# ---------Currently converting web page #  789
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  790
# ---------Currently converting web page #  791
# ---------Currently converting web page #  792
# ---------Currently converting web page #  793
# ---------Currently converting web page #  794
# ---------Currently converting web page #  795
# ---------Currently converting web page #  796
# ---------Currently converting web page #  797
# ---------Currently converting web page #  798
# ---------Currently converting web page #  799
# ---------Currently converting web page #  800
# ---------Currently converting web page #  801
# ---------Currently converting web page #  802
# ---------Currently converting web page #  803
# ---------Currently converting web page #  804
# ---------Currently converting web page #  805
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  806
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  807
# ---------Currently converting web page #  808
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  809
# ---------Currently converting web page #  810
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  811
# ---------Currently converting web page #  812
# ---------Currently converting web page #  813
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  814
# ---------Currently converting web page #  815
# ---------Currently converting web page #  816
# ---------Currently converting web page #  817
# ---------Currently converting web page #  818
# ---------Currently converting web page #  819
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  820
# ---------Currently converting web page #  821
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  822
# ---------Currently converting web page #  823
# ---------Currently converting web page #  824
# ---------Currently converting web page #  825
# ---------Currently converting web page #  826
# ---------Currently converting web page #  827
# ---------Currently converting web page #  828
# ---------Currently converting web page #  829
# ---------Currently converting web page #  830
# ---------Currently converting web page #  831
# ---------Currently converting web page #  832
# ---------Currently converting web page #  833
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  834
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  835
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  836
# ---------Currently converting web page #  837
# ---------Currently converting web page #  838
# ---------Currently converting web page #  839
# ---------Currently converting web page #  840
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  841
# no estimate_salary_range
# no estimate_salary_point
# no job_description
# ---------Currently converting web page #  842
# ---------Currently converting web page #  843
# ---------Currently converting web page #  844
# ---------Currently converting web page #  845
# ---------Currently converting web page #  846
# ---------Currently converting web page #  847
# ---------Currently converting web page #  848
# ---------Currently converting web page #  849
# ---------Currently converting web page #  850
# ---------Currently converting web page #  851
# ---------Currently converting web page #  852
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  853
# ---------Currently converting web page #  854
# ---------Currently converting web page #  855
# ---------Currently converting web page #  856
# ---------Currently converting web page #  857
# ---------Currently converting web page #  858
# ---------Currently converting web page #  859
# ---------Currently converting web page #  860
# ---------Currently converting web page #  861
# ---------Currently converting web page #  862
# ---------Currently converting web page #  863
# ---------Currently converting web page #  864
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  865
# ---------Currently converting web page #  866
# ---------Currently converting web page #  867
# ---------Currently converting web page #  868
# ---------Currently converting web page #  869
# ---------Currently converting web page #  870
# ---------Currently converting web page #  871
# ---------Currently converting web page #  872
# ---------Currently converting web page #  873
# ---------Currently converting web page #  874
# ---------Currently converting web page #  875
# ---------Currently converting web page #  876
# ---------Currently converting web page #  877
# ---------Currently converting web page #  878
# ---------Currently converting web page #  879
# ---------Currently converting web page #  880
# ---------Currently converting web page #  881
# ---------Currently converting web page #  882
# ---------Currently converting web page #  883
# ---------Currently converting web page #  884
# ---------Currently converting web page #  885
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  886
# ---------Currently converting web page #  887
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  888
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  889
# ---------Currently converting web page #  890
# ---------Currently converting web page #  891
# ---------Currently converting web page #  892
# ---------Currently converting web page #  893
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  894
# ---------Currently converting web page #  895
# ---------Currently converting web page #  896
# no estimate_salary_point
# ---------Currently converting web page #  897
# ---------Currently converting web page #  898
# ---------Currently converting web page #  899
# ---------Currently converting web page #  900
# ---------Currently converting web page #  901
# ---------Currently converting web page #  902
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  903
# ---------Currently converting web page #  904
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  905
# ---------Currently converting web page #  906
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  907
# ---------Currently converting web page #  908
# ---------Currently converting web page #  909
# ---------Currently converting web page #  910
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  911
# ---------Currently converting web page #  912
# ---------Currently converting web page #  913
# ---------Currently converting web page #  914
# ---------Currently converting web page #  915
# ---------Currently converting web page #  916
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  917
# no estimate_salary_range
# no estimate_salary_point
# ---------Currently converting web page #  918
# No rating
# no estimate_salary_range
# no estimate_salary_point
# no company link
# ---------Currently converting web page #  919
# ---------Currently converting web page #  920
# ---------Currently converting web page #  921
# ---------Currently converting web page #  922
# ---------Currently converting web page #  923
# ---------Currently converting web page #  924
# ---------Currently converting web page #  925
# no estimate_salary_range
# no estimate_salary_point

# %%
print(data[0].keys())
# Out:
# dict_keys(['title', 'company_name', 'rating', 'location', 'estimate_salary_range', 'estimate_salary_point', 'job_description', 'company_link'])

# %%
df = pd.DataFrame(data, columns = data[0].keys())
print(df.head())
# Out:
#                                   title                company_name rating  \
# 0                        Sales Engineer                      Xcalar    3.3
# 1                     Big Data Engineer  Meridian Technologies, Inc    4.0
# 2    Machine Learning Engineer (REMOTE)               Scalable Path    5.0
# 3  Computational Science Engineer (CSE)                       Q Bio    4.4
# 4   Software Engineer, Machine Learning                    Netskope    4.1
#
#            location estimate_salary_range estimate_salary_point  \
# 0      New York, NY           $98K-$118K               $107,133
# 1       Seattle, WA           $85K-$114K                $97,989
# 2     San Diego, CA                    -1                    -1
# 3  Redwood City, CA           $72K-$106K                $89,277
# 4   Santa Clara, CA          $160K-$178K               $166,979
#
#                                      job_description  \
# 0  Xcalar is pushing the limits of technology to ...
# 1  We are looking for strong Big Data Engineers a...
# 2  Scalable Path is looking for a Machine Learnin...
# 3  As part of the team at Q you will work alongsi...
# 4  About Netskope\nToday, there's more data and u...
#
#                                         company_link
# 0  /Overview/Working-at-Xcalar-EI_IE1259182.11,17...
# 1  /Overview/Working-at-Meridian-Technologies-Inc...
# 2
# 3  /Overview/Working-at-Q-Bio-EI_IE1755895.11,16.htm
# 4  /Overview/Working-at-Netskope-EI_IE717917.11,1...

# %%
df_cleaned = df.drop_duplicates()
print("length of original dataset: ",len(df))
print("length of cleaned dataset: ",len(df_cleaned))
# Out:
# length of original dataset:  926
# length of cleaned dataset:  536

# %%
df_cleaned.to_csv('glassdoor_data_ML.csv', index=False)
